# %%
import pandas as pd

# %%
df = pd.read_csv('data_frames_basics.csv', parse_dates=["day"])

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0          6   Rain
# 2017-01-02          NaN          7  Sunny
# 2017-01-03         28.0          2   Snow
# 2017-01-04         24.0          7   Snow
# 2017-01-05          NaN          4   Rain
# 2017-01-06         31.0          2  Sunny

# %%
new_df = df.fillna(0)

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0          6   Rain
# 2017-01-02          0.0          7  Sunny
# 2017-01-03         28.0          2   Snow
# 2017-01-04         24.0          7   Snow
# 2017-01-05          0.0          4   Rain
# 2017-01-06         31.0          2  Sunny

# %%
new_df = df.fillna({'temperature':0,'event':'no event'})

# %%
depression_df = pd.read_excel('depression.xls')

# %%
depression_df
# Out:
#      Hospt       Treat        Outcome     Time  AcuteT  Age  Gender
# 0        1     Lithium     Recurrence   36.143     211   33       1
# 1        1  Imipramine  No Recurrence  105.143     176   49       1
# 2        1  Imipramine  No Recurrence   74.571     191   50       1
# 3        1     Lithium     Recurrence   49.714     206   29       2
# 4        1     Lithium  No Recurrence   14.429      63   29       1
# 5        1     Placebo     Recurrence    5.000      70   30       2
# 6        1     Lithium  No Recurrence  104.857      55   56       1
# 7        1     Placebo     Recurrence    2.857     512   48       1
# 8        1     Placebo  No Recurrence  102.429     162   22       2
# 9        1     Placebo     Recurrence   55.714     306   61       2
# 10       1  Imipramine  No Recurrence  106.429     165   58       1
# 11       1  Imipramine  No Recurrence  105.143     129   31       1
# 12       1  Imipramine  No Recurrence   83.000     428   44       1
# ...

# %%
depression_df['Gender'] = depression_df['Gender'].map({1:'Female', 2:'Male'})

# %%
depression_df
# Out:
#      Hospt       Treat        Outcome     Time  AcuteT  Age  Gender
# 0        1     Lithium     Recurrence   36.143     211   33  Female
# 1        1  Imipramine  No Recurrence  105.143     176   49  Female
# 2        1  Imipramine  No Recurrence   74.571     191   50  Female
# 3        1     Lithium     Recurrence   49.714     206   29    Male
# 4        1     Lithium  No Recurrence   14.429      63   29  Female
# 5        1     Placebo     Recurrence    5.000      70   30    Male
# 6        1     Lithium  No Recurrence  104.857      55   56  Female
# 7        1     Placebo     Recurrence    2.857     512   48  Female
# 8        1     Placebo  No Recurrence  102.429     162   22    Male
# 9        1     Placebo     Recurrence   55.714     306   61    Male
# 10       1  Imipramine  No Recurrence  106.429     165   58  Female
# 11       1  Imipramine  No Recurrence  105.143     129   31  Female
# 12       1  Imipramine  No Recurrence   83.000     428   44  Female
# ...

# %%
friends_df = pd.read_excel('friends.xls')

# %%
friends_df
# Out:
#             Friends
# 0      Opposite sex
# 1     No difference
# 2      Opposite sex
# 3     No difference
# 4      Opposite sex
# 5          Same sex
# 6          Same sex
# 7          Same sex
# 8      Opposite sex
# 9     No difference
# 10         Same sex
# 11    No difference
# 12    No difference
# 13     Opposite sex
# 14         Same sex
# 15     Opposite sex
# 16     Opposite sex
# 17     Opposite sex
# 18    No difference
# 19         Same sex
# 20    No difference
# 21    No difference
# 22    No difference
# 23    No difference
# 24     Opposite sex
# 25     Opposite sex
# 26    No difference
# 27    No difference
# 28     Opposite sex
# 29     Opposite sex
# ...             ...
# 1170  No difference
# 1171   Opposite sex
# 1172  No difference
# 1173   Opposite sex
# 1174   Opposite sex
# 1175  No difference
# 1176   Opposite sex
# 1177  No difference
# 1178  No difference
# 1179       Same sex
# 1180   Opposite sex
# 1181   Opposite sex
# 1182  No difference
# ...

# %%
friends_df = friends_df.groupby('Friends').count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-53eb911a0122> in <module>()
# ----> 1 friends_df = friends_df.groupby('Friends').count()
#
# /Users/housing/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# /Users/housing/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# ...

# %%
friends_df

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-5f6312cf8f08> in <module>()
# ----> 1 friends_df['No difference']
#
# /Users/housing/anaconda2/lib/python2.7/site-packages/pandas/core/base.pyc in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: No difference'
